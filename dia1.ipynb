# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# Variables

# %%
# snake_case:
frase_famosa = "Hola mundo"

# orden de ejecucion
fruta = "Naranaja"
print(fruta)

cantidad_de_frutas_ = 4
print(cantidad_de_frutas_)

fruta = "Banana"
print(fruta)
# Out:
# Naranaja
# 4
# Banana

# %% [markdown]
# Tipo de datos

# %%
edad = 28 #Integer
altura = 1.80 # Float
nombre = "Micaela" #String
Feliz = True #Bool

print(edad)
print(altura)
print(nombre)
print(Feliz)

print(edad, altura, nombre, Feliz)
# Out:
# 28
# 1.8
# Micaela
# True
# 28 1.8 Micaela True

# %% [markdown]
# Challenge

# %%
nombre = ("Micaela")
edad = 27
ciudad = ("Asunción")

print(nombre, edad, ciudad)
# Out:
# Micaela 27 Asunción

# %% [markdown]
# Operaciones aritméticas
# · + suma
# · - resta
# · * multiplicacion
# · / division
# · // division entera (sin decimales)
# · % resto ( modulo)

# %%
producto1 = "Papas fritas"
costo_proucto1 = 15000
producto2= "Coca cola"
costo_producto2= 14000
capital = 50000
dolar = 6700

#Realizamos la suma
costo_total= costo_proucto1 + costo_producto2
print(costo_total)

# %% [markdown]
# challenge 2
# Suma: asignar dos números en dos variables diferentes cantidad_de_manzanas y cantidad_de_naranjas. Luego sumar ambas variables en cantidad_de_frutas. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable frutas_vendidas. Luego, asignar la resta entre cantidad_de_frutas y frutas_vendidas a la variable frutas_restantes. Imprimir la última variable.

# %%
#suma
cantidad_manzanas = 5
cantidad_naranjas = 7
cantidad_de_frutas = cantidad_manzanas + cantidad_naranjas
print("cantidad de frutas: ", cantidad_de_frutas)

#resta
frutas_vendidas = 8
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print("frutas restantes:", frutas_restantes)
# Out:
# cantidad de frutas:  12
# frutas restantes: 4

# %%
nombre = "Micaela" 
apellido = "Insfran"
espacio = " "
print(nombre)
print(apellido)

#Concatenar los strings
print(nombre + espacio + apellido)
print(f"Hola mi nombre es {nombre} y mi apellido es {apellido} ")
# Out:
# Micaela
# Insfran
# Micaela Insfran
# Hola mi nombre es Micaela y mi apellido es Insfran

# %% [markdown]
# Challenge 🤺 - 10m
# Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
nombre = "Paz " 
apellido = "Adrian, "
print("Hola, mi nombre es "+ nombre + apellido + "mucho gusto!")
# Out:
# Hola, mi nombre es Paz Adrian, mucho gusto!

# %% [markdown]
# El input sirve ara que el programa le haga una pregunta al usuario y guarde lo que responda por teclado

# %%
nombre = input("Cual es tu nombre?")
print(nombre)
# Out:
# Micaela

# %%
#Solicitar al usuario un producto
producto =  input ("Que producto deseas?")
print(producto)

# Solicitar al usuario que ingrese la cantidad de producto
cantidad_de_producto = input ("Que cantidad de productos deseas")
print(cantidad_de_producto)

print(f'El usuario quiere un {producto} en {cantidad_de_producto} cantidades')
# Out:
# mouse
# 14
# El usuario quiere un mouse en 14 cantidades

# %% [markdown]
# Tipos de datos

# %%
edad = 19
print (type(edad))

nombre = "Claudia"
print(type(nombre))

temperatura = 36.5
print(type(temperatura))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
edad = input("Ingrese su edad")
print(type(edad))

cantidad_de_anhos

# %%
#Funcion Mate
def preparar_mate():
    print("Proceso iniciado porfavor aguarde un momento")
    print("Pedido completado")
#llamar a la funcion
preparar_mate()
preparar_mate()
preparar_mate()
# Out:
# Proceso iniciado porfavor aguarde un momento
# Pedido completado
# Proceso iniciado porfavor aguarde un momento
# Pedido completado
# Proceso iniciado porfavor aguarde un momento
# Pedido completado

# %%
def skincare():
    print ("Lavar cara con agua y jabon")
    print ("Secar exceso de agua")
    print ("Aplicar serum")
    print ("Aplicar crema hidratante")
    print ("Aplicar protector solar")
    print ("Listo")

skincare()
skincare()
skincare()
# Out:
# Lavar cara con agua y jabon
# Secar exceso de agua
# Aplicar serum
# Aplicar crema hidratante
# Aplicar protector solar
# Listo
# Lavar cara con agua y jabon
# Secar exceso de agua
# Aplicar serum
# Aplicar crema hidratante
# Aplicar protector solar
# Listo
# Lavar cara con agua y jabon
# Secar exceso de agua
# Aplicar serum
# Aplicar crema hidratante
# Aplicar protector solar
# Listo

# %%
# Challenge 6
# Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas.

def mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica):
    print(f"El elemento a comprar es {elemento}, y cuenta con las siguientes caracteristicas: {primera_caracteristica}, {segunda_caracteristica}, {tercera_caracteristica}")

def producto_a_comprar():
    elemento = input("Ingrese el elemento a comprar: ")
    primera_caracteristica = input("Ingrese una caracteristica del elemento a comprar: ")
    segunda_caracteristica = input("Ingrese otra caracteristica del elemento a comprar: ")
    tercera_caracteristica = input("Ingrese una ultima caracteristica del elemento a comprar: ")

    mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica)

producto_a_comprar()
# Out:
# El elemento a comprar es elemento, y cuenta con las siguientes caracteristicas: segunda caracteristica, ,

# %%
pulgadas = input("¿Cuántas pulgadas es la television")
def preguntar():
    resolucion = input("¿Cuál es la resolución que tiene la TV")
    print(f"La TV tiene {pulgadas} pulgadas y una resolucion de {resolucion}")

preguntar()
# Out:
# La TV tiene 42 pulgadas y una resolucion de hd
