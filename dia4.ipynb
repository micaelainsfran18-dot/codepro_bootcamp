# %% [markdown]
# Diccionario

# %% [markdown]
# ## Challenge 1 🤺 10m
# Escribir un programa que cree un `diccionario vacío` y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le `pida al usuario`.
#
# Cada vez que se `añada` un nuevo dato debe `imprimirse` el contenido del diccionario.

# %%
#   
datos = {}
datos = {'Nombre':input("Ingrese su nombre")}
print(datos)

datos = {'Apellido':input("Ingrese su apellido")}
print(datos)

datos = {'Sexo':input("Ingrese su genero")}
print(datos)

datos = {'Telefono':input("Ingrese su telefono")}
print(datos)

datos = {'Correo':input("Ingrese su correo electronico")}
print(datos)

print('Gracias por Regalar sus datos :)')

# %%
#Soucion de kathe
diccionario1 = {} # Primero creamos el diccionario
print(diccionario1)

clave = 'dato'

while True:
    clave = input('Ingrese el dato que va ingresar')

    if clave == 'salir':
        print('Se ha terminado de ingresar los datos')
        break

    valor = input ('Ingrese el dato especificado anteriormente')

    diccionario1[clave]= [valor]
    print(diccionario1)

# %%
#funcion de diccionario
#pedir la usuario  dato que desea "clave"
#pedir el "valor" del dato
# guardar el dato en el diccionario
# imprimir 
# repetir hasta que el usuario decida 


mi_contacto = {"Nombre: ":"Micaela", "Apellido: ":"Insfran","Correo: ":"micaela.insfran18@gmail.com","Ciudad: ": "Asuncion","Telefono: ": "0982773593"}
print(mi_contacto)

mi_contacto["Correo: "]
print(mi_contacto["Correo: "])

producto = {
    "nombre: ": "Bateria",
    "precio: ": 45000, #int
    "stock: " : True, #bool
}

#Acceder a la clave de un diccionario

mi_contacto["email: "] = "penguin@gmail.com"
print(mi_contacto)

#Usar netodos del diccionario 

print(mi_contacto.keys()) #devuele todos las claves de los usuarios
print(mi_contacto.values()) #devuelve todos los valores al usuario 
print(mi_contacto.items()) #develve el par 

#anhadir datos 

mi_contacto["ciudad:"] = "Asuncion"
print(mi_contacto)

#eliminar el ultimo valor/clave
mi_contacto.popitem("Correo")
print(mi_contacto)

#eliminar datos del diccionario por clave

del mi_contacto ["Apellido:"]
print(f"Este es el diccionario con la clave eliminada: {mi_contacto}")

#Los diccionarios son iterables 

for i in mi_contacto.values():
    print(i)

for i in mi_contacto.keys():
    print(i)

for clave,valor in mi_contacto.item():
    print(clave)

# %% [markdown]
# ## Challenge 2 🤺 - 20 min
#
# Crear una tarjeta personal. El usuario (mediante `input`) puede elegir:
#
# 1. `Crear` datos nuevos
# 2. `Modificar` datos
# 3. `Eliminar` datos

# %%
print( "Tarjeta personal")
datos ={
    "Nombre:": input("Ingrese nombre: "),
    "edad:": "22",
    "dato a ser eliminado:": "estudiante",
}
print(datos)




nombre= input("Ingrese nombre: ")
edad = input("Ingrese edad: ")

# %%
tarjeta_personal = {"nombre": "tobias salgueiro", "edad": "19", "email": "tobiassalgueiro24@gmail.com", "direccion": "lambare"

}
def modificar():
    print(tarjeta_personal)
    if tarjeta_personal["nombre"]:
     tarjeta_personal["nombre"] = input("ingrese nombre")
    print(tarjeta_personal)
    if tarjeta_personal["edad"]:
     tarjeta_personal["edad"] = input("ingrese su edad")
    print(tarjeta_personal)

# %%
tarjeta={}

while True:
    accion=int(input("que desea realizar,1=crear,2=modificar,3=eliminar "))
  
    if accion==1:
        clave_1=input("ingrese la clave")
        valor_1=input("ingrese el valor para la clave")
        tarjeta[clave_1]=valor_1
        print(tarjeta)
    elif accion==2:
        print("los valores que podes modificar son son")
        print(tarjeta.items())
        clave_1=input("ingrese la clave a cambiar")
        modificacion=input("ingrese el valor nuevo")
        tarjeta[clave_1]=modificacion
        print(tarjeta)
    elif accion==3:
        print("los valores que podes eliminar son")
        print(tarjeta.keys())
        clave_1=input("ingresa el valor a eliminar")
        del tarjeta[clave_1]
        print(tarjeta)
    parar=input("si desea salir ingrese si sino ingrese no")
    if parar=="si":
        break

# %% [markdown]
# ## Challenge 3 🤺
# Crear una agenda de contactos. El usuario puede elegir:
#
# 1. `Mostrar` los contactos
# 2. `Crear `contacto
# 3. `Modificar` datos del contacto

# %%
agenda_contactos= {
    "maria": "08001",
    "lucas": "08002",
    "carmen":"08003",
    }

#1= print(agenda_contactos.items)
#2= agenda_contactos[input("Crea contacto,ingresando nombre")] = input("Ingresa numero de telefono"))
#3=

# %% [markdown]
# Porgramacion orientada a objetos

# %%
#molde
class Perro:
    #atributos de clase
    cabeza = 1
    patas = 4
    especie = 'canina'
    #atributo de instancia 
    def __init__(self,nombre, raza, color):
        self.nombre= nombre
        self.raza= raza
        self.color= color 

#creando un objeto -## metodo## instanciar un objeto
perro1 = Perro('Firulais','mestizo',"marron")#propio de este metodo
perro2 = Perro("choco","delmer","blanco")
perro3 = Perro("puppy","san bernardo","marron/blanco")

print(perro1.especie)
print(perro1.raza)
print(perro1.color)
# Out:
# canina
# mestizo
# marron

# %% [markdown]
# ## Challenge 🤺  - 15 min
#
# Crear una clase animales que tenga atributo de clase y de instancia.
#
# - Atributos de clase: `especie`.
# - Atributos de instancia: `nombre` & `color`
#
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo `{nombre}` y soy un ave de color `{color}`".

# %%
#Atributo de clase 
class Animal:
    tipo = "Felina"
 
#atributo de instancia
    def __init__(self,nombre,color):
        self.nombre= nombre
        self.color = color
#crear el objeto
gato1 = Animal('fibi','verde')
#print(f"Me llamo {nombre} y soy un gato color")

# %%
#atributo de clase
class Coche:
    tipo= "vehiculo"
#atributo de instancia
    def __init__(self,modelo,posicion=0):
        self.modelo = modelo
        self.posicion = posicion 
#definir otras acciones
    def acelerar(self,metros):
        self.posicion +=metros
        print(f'El vehiculo modelo {self.modelo} acelera y avanza {metros}. Nueva posicion: {self.posicion}')

    def girar(self,direccion):
        print(f'El modelo {self.modelo} avanza y gira a la {direccion} direccion')


coche1 = Coche('Toyota')
coche1.acelerar(1)
coche1.girar("izquierda")
# Out:
# El vehiculo modelo Toyota acelera y avanza 1. Nueva posicion: 1
# El modelo Toyota avanza y gira a la izquierda direccion

# %% [markdown]
# ## Challenge 2🤺 - 15 min
# Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.
#
# Ejemplo: "Cuando hablo, digo X".
# Ejemplo: "Cuando me muevo, hago X".

# %%
#class Perro:
   # especie = "canina"
    #def __init__(self,nombre):
     #      self.nombre = nombre
            
   #def digo (digo):
    #     self.digo 
    #      print(f'Cuando {s,')

# %%
class Perro:

    especie= 'perro'

    def __init__(self, nombre, color, caracteristica):
        self.nombre= nombre
        self.color= color
        self.caracteristica= caracteristica

#crear el objeto
firulais= Perro('firulais', 'marron', 'ladra')
print(f'cuando yo hablo Maximo el {firulais.especie} {firulais.color} {firulais.caracteristica}')

momo= Perro('Momo', 'negro', 'mueve la cola')
print(f'cuando yo digo PASEO! Momo el {momo.especie} {momo.color} {momo.caracteristica}')
# Out:
# cuando yo hablo Maximo el perro marron ladra
# cuando yo digo PASEO! Momo el perro negro mueve la cola

# %% [markdown]
# Herencia

# %%
class AnimalDeGranja:
    #atributo de clase
    tipo= "animal de granja"

    #atributo de instancia
    def __init__(self, nombre, color, sonido):
        self.nombre = nombre
        self.color = color
        self.sonido = sonido
    #metodos
    def hablar (self):
        print(f'Hablo y digo {self.sonido}')
    
    def presentarse (self):
        print(f'Hola soy {self.nombre}')

class Gallina(AnimalDeGranja):
    pass
    
class Vaca(Gallina):
    patas = 4

    def mujir (self):
        print("Muuuu")

galina1 =  Gallina("Hortencia","marron,", "cocorococo")

# %% [markdown]
# ## Challenge 3🤺 - 15 min
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.
#
# Observación: Editar las clases hijas para que no se inicialicen.

# %%
class Persona:
        def __init__(self,nombre, edad):
         self.nombre = nombre
         self.edad = edad

class Estudiante(Persona):
        pass

class Profesor(Persona):
        pass
     
        
Estudiante1 = Estudiante("Micaela","22")
Profesor1= Profesor("Carlos","45")

print("Estudiante: ")
print(Estudiante1.nombre)
print(Estudiante1.edad)
print("\nProfesor:")
print(Profesor1.nombre)
print(Profesor1.edad)
# Out:
# Estudiante:
# Micaela
# 22
#
# Profesor:
# Carlos
# 45

# %% [markdown]
# ## Challenge 4 🤺 - 20 min
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#
# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

# %%
#crear dos personajes
#class1 heroe
#class2 villano
#asignar poderes atraves de metodos de instancia
#

class Personajes:

    tipo= 'protagonista'

    def __init__(self, nombre, poder):
        self.nombre= nombre
        self.poder = poder
       
#crear el objeto
heroe = Personajes('Heroe', 'volar')
print(f'Yo me llamo Super {heroe.nombre}, y mi poder es {heroe.poder}')

villano = Personajes ("Villano", "velocidad")
print(f'Yo soy el super {villano.nombre},y mi poder es {villano.poder}')
# Out:
# Yo me llamo Super Heroe, y mi poder es volar
# Yo soy el super Villano,y mi poder es velocidad
